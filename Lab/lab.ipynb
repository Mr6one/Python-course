# 24     0.000000e+00  1.255970e+09
# 25     0.000000e+00  5.958800e+07
# 26     0.000000e+00  1.311050e+09
# 27     0.000000e+00  6.065800e+07
# 28     0.000000e+00  1.288630e+09
# 29     0.000000e+00  5.905290e+07
# ...             ...           ...
# 37558  3.113110e+06  2.270460e+08
# 37559  6.702560e+06  1.040380e+08
# 37560  1.019210e+07  6.773980e+07
# 37561  4.103980e+07  3.310870e+08
# 37562  8.157260e+07  3.543110e+09
# 37563  4.893110e+07  1.155730e+09
# 37564  5.604010e+06  9.902520e+07
# 37565  2.009340e+06  2.116430e+08
# 37566  2.447040e+06  1.877440e+08
# 37567  2.295680e+06  1.268790e+08
# 37568  5.196670e+06  4.556540e+08
# 37569  1.504760e+06  1.793970e+08
# 37570  2.999650e+06  4.187970e+08
# 37571  1.025180e+06  5.147300e+08
# 37572  3.900790e+06  1.183970e+08
# 37573  2.028040e+07  3.412490e+08
# 37574  4.901450e+06  7.038110e+07
# 37575  1.883140e+08  3.985740e+09
# 37576  2.508360e+09  2.501920e+09
# 37577  1.205590e+08  2.154240e+09
# 37578  9.196140e+05  1.793920e+08
# 37579  8.382230e+05  7.142090e+07
# 37580  2.493120e+07  4.326770e+08
# 37581  1.126420e+07  3.775560e+08
# 37582  1.644680e+07  2.269270e+09
# 37583  5.116500e+07  5.450080e+09
# 37584  9.307450e+06  5.959400e+08
# 37585  5.688700e+07  9.769940e+08
# 37586  5.466790e+07  9.348810e+08
# 37587  1.777800e+07  6.741510e+08
#
# [37588 rows x 13 columns]

# %% [markdown]
# Поясним значения хранящиеся в колонках
#  - date - дата измерений
#  - name - полное название монеты
#  - symbol - сокращенное название монеты
#  - price - средняя цена монеты за торговый день в USD
#  - txCount - количество транзакций в сети данной монеты
#  - txVolume - объем монет переведенных между адресами в сети данной монеты
#  - activeAddresses - количество адресов совершавших а данный день транзации в сети данной монеты
#  - open - цена монеты в начале торгов данного дня
#  - close - цена монеты в конце торгов данного дня
#  - high - самая высокая цена данной монеты в течение данного торгового дня
#  - low - самая низкая цена данной монеты в течение данного торгового дня
#  - volume - объем торгов данной монетой на биржах в данный день
#  - market - капитализация данной монеты в данный день

# %% [markdown]
# #### Изучим полученные данные. Ответьте на следующие вопросы (вставляйте клетки с кодом и тектом ниже):
# #### 1. Сколько всего различных монет представлено в датасете? (0.4 балла)

# %%
len(coins['name'].unique())
# Out:
# 70

# %% [markdown]
# #### 2. За какой период данные мы имеем? (0.4 балла)

# %%
[coins.index.min(), coins.index.max()]
# Out:
# ['2013-04-28', '2018-06-06']

# %% [markdown]
# #### 3. Есть ли пропуски в данных? Какой природы эти пропуски? (0.5 балла)

# %%
print(coins.isnull().sum())

gaps_num = 0
for i in range(coins.shape[0]-1):
    time_difference = pd.to_datetime(coins.index[i+1]) - pd.to_datetime(coins.index[i])
    if time_difference.days > 1:
        gaps_num += 1
        
if gaps_num == 0:
    print('Пропусков между датами нет')
else:
    print('Число пропусков между датами:', gaps_num)
# Out:
# price               327
# txCount            1520
# txVolume           1830
# activeAddresses    1520
# symbol                0
# name                  0
# open                  0
# high                  0
# low                   0
# close                 0
# volume                0
# market                0
# dtype: int64
# Пропусков между датами нет

# %% [markdown]
# #### 4. У какой монеты и когда была самая высокая цена? (0.2 балла)

# %%
coins[coins['price'] == coins['price'].max()][['name']]
# Out:
#                name
# date
# 2017-12-17  Bitcoin

# %% [markdown]
# #### 5. У какой монеты самая высокая и самая низкая суммарная капитализация? Постройте круговую диаграмму с долями. (0.5 балла)

# %%
capitalized = coins.groupby(['name'])[['market']].sum().reset_index()

max_cap = capitalized['market'].max()
min_cap = capitalized['market'].min()
coin_name_with_max = capitalized[capitalized['market'] == max_cap]['name'].values[0]
coin_name_with_min = capitalized[capitalized['market'] == min_cap]['name'].values[0]

print('min:', coin_name_with_min, min_cap)
print('max:', coin_name_with_max, max_cap)

plt.pie(
    capitalized['market'], autopct='%.1f', labels=capitalized['name'], radius=3
)
plt.show()
# Out:
# min: KingN Coin 10608251.0
# max: Bitcoin 57439466431000.0

# %% [markdown]
# ## 2. Визуализация (1 балл)

# %% [markdown]
# Самая интересная часть работы аналитика состоит во внимательном вглядывании в правильно выбранные и построенные графики.

# %% [markdown]
# #### Реализуйте функцию для визуализации цен выбранной валюты за выбранный диапазон дат.
# На графике должны быть видны цены начала и конца продаж. А так же минимальная и максимальная цена за этот день.
# Подпишите график и оси координат. Добавьте сетку. Увеличьте размер изображения.
# Можете попробовать использовать matplotlib.finance.candlestick_ohlc (mpl_finance.candlestick_ohlc), но можно и без него.

# %%
def plot_fancy_price_action(coins, symbol, start_date, end_date):
    data = coins[(coins['symbol'] == symbol) & (coins.index >= start_date) & 
                 (coins.index <= end_date)]
    
    plt.figure(figsize=(50, 20))
    plt.plot(data.index, data['open'], label = 'Start Of Sales')
    plt.plot(data.index, data['close'], label = 'End Of Sales')
    plt.plot(data.index, data['low'], label = 'Min price')
    plt.plot(data.index, data['high'], label = 'Max price')
    
    plt.title('The Dependence Between Selected Currency And Selected Date', fontsize=60)
    plt.ylabel('Value', fontsize=50)
    plt.xlabel('Date', fontsize=50)
    plt.tick_params(axis='both', labelsize=28)
    plt.xticks(data.index[::len(data.index)//10])
    plt.legend(loc='upper right', fontsize=45)
    
    plt.grid()
 
    plt.show()

# %% [markdown]
# Посмотрим, что получилось:

# %%
plot_fancy_price_action(coins=coins, symbol='VERI', start_date='2013-06-01', end_date='2019-06-30')

# %% [markdown]
# Никакого датасаенса в этом задании нет. Просто аналитик должен уметь строить графики, либо знать готовые инструменты.

# %% [markdown]
# ## 3. Накачка и сброс (1 балл)
# Криптовалютные биржи до сих пор остаются маргинальным местом, эдаким диким западом финансового мира. Как следствие, здесь процветают схемы относительно
# честного отъема денег. Одна из них - pump'n'dump (накачка и сброс). Она выглядит следуюшим образом. Несколько крупных игроков или много мелких договариваются
# вместе купить малоизвестную монету с низкой ценой и объемом торгов. Это приводит к мгновенному взлету цены (pump), далее приходят неопытные игроки в надежде
# успеть заработать на таком росте. В этот момент организаторы схемы начнают все продавать (dump). Весь процесс занимает от нескольких минут до нескольких часов.
#
# #### Ваша задача найти самый сильный pump'n'dump монеты на заданном промежутке времени. Для этого для каждого дня определим число pnd равное отношению максимальной цены монеты в данный день к максимуму из цен открытия и закрытия в тот же день. Нужно найти день когда pnd был максимален и величину pnd.

# %%
def find_most_severe_pump_and_dump(coins, symbol, start_date, end_date):
    data = coins[(coins['symbol'] == symbol) & (coins.index >= start_date) & 
                 (coins.index <= end_date)]
    pnds = list()
    for i in range(data.shape[0]):
        pnds.append(data['high'].values[i] / max(data['close'].values[i], data['open'].values[i]))
    
    data.insert(12, 'pnds', pnds)
    return data[data['pnds'] == data['pnds'].max()][['pnds']]

# %%
find_most_severe_pump_and_dump(coins, symbol='BTC', start_date='2017-06-01', end_date='2018-06-01')
# Out:
#                 pnds
# date
# 2017-11-29  1.142894

# %% [markdown]
# #### Сравните эти значения для разных монет.

# %%
pnds = list()
coins_ = list()
for coin in coins['symbol'].unique():
    pnds.append(find_most_severe_pump_and_dump(coins, symbol=coin, start_date='2017-06-01', end_date='2018-06-01'))
    coins_.append(coin)

pnds_ = list()
for i in range(len(pnds)):
    pnds_.append(pnds[i]['pnds'].values[0])

plt.figure(figsize=(40, 20))
plt.bar(coins_, pnds_)
plt.tick_params(axis='both', labelsize=12)
plt.show()

# %% [markdown]
# ## 4. Окупаемость инвестиций (1 балл)

# %% [markdown]
# #### Вам нужно посчитать окупаемость инвестиций в криптовалюты на заданном промежутке времени. Окупаемость определяется как отношение изменения цены портфеля к исходной цене портфеля. Цена портфеля - это суммарная стоимость (в USD) всех монет в портфеле.
# investments - dict в котором ключи - это названия монет, значения - это сумма вложений в эту монету (в USD)

# %%
def compute_roi(coins, investments, start_date, end_date):
    data = coins[coins['symbol'].isin(investments.keys())]
    start_sum = sum(list(investments.values()))
    end_sum = 0
    for coin in list(investments.keys()):
        coefficient = data[data['symbol'] == coin].loc[end_date]['close'] / data[data['symbol'] == coin].loc[start_date]['open']
        end_sum += investments[coin]*coefficient
    
    print((end_sum-start_sum)/start_sum)

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2018-04-04', end_date='2018-06-01')
# Out:
# -0.027221083037452142

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2013-05-28', end_date='2018-06-06')
# Out:
# 51.35085448945653

# %% [markdown]
# ## 5. Технический анализ (1 балл)

# %% [markdown]
# Технический анализ это способ предсказания поведения графика по некоторым вспомогательным величинам построенным по исходному графику. Один из простейших методов технического анализа - границы Болинджера. Кто-то верит, что график касаясь границы от него должен отражаться.

# %% [markdown]
# #### Нарисуйте график цены, скользящее среднее и [границы Боллинджера](https://en.wikipedia.org/wiki/Bollinger_Bands) c параметрами N (window) = 21, K (width) = 2.
#
# Границы считаются очень просто: (MA + Kσ) и (MA - Kσ), где MA - скользящее среднее за N дней, а σ - скользящее стандартное отклонение за N дней.
#
# Тут вам поможет функция rolling для подсчёта среднего и стандартного отклонения по скользящему окну.
#
# Не забудьте подписать график и оси, отрисовать легенду и выбрать для нее лучшее расположение.

# %%
def plot_bollinger_bands(coins, symbol, window, width):
    data = coins[coins['symbol'] == symbol]
    windows = data['price'].rolling(window)
    
    plt.figure(figsize=(50, 20))
    plt.plot(data['price'], label = 'Price')
    plt.plot(windows.mean(), label = 'Average')
    plt.plot(windows.mean()+width*windows.std(), label = 'Upper Band')
    plt.plot(windows.mean()-width*windows.std(), label = 'Lower Band')
    
    plt.title('Technical Analysis', fontsize=60)
    plt.ylabel('Value', fontsize=50)
    plt.xlabel('Date', fontsize=50)
    plt.tick_params(axis='both', labelsize=28)
    plt.xticks(data.index[::len(data.index)//10])
    plt.legend(loc='upper left', fontsize=45)
    
    plt.grid()
    
    plt.show()

# %%
plot_bollinger_bands(coins=coins, symbol='EOS', window=21, width=2)  # тут должен появиться график

# %% [markdown]
# #### Сделайте вывод о том, выполнялось ли правило Боллинджера.
# #### Выполнялось

# %% [markdown]
# ## 6. Капитализация как индикатор (1 балл)

# %% [markdown]
# Многие люди, которые торгуют криптовалютой, любят смотреть на капитализацию. Давайте поймём почему.

# %% [markdown]
# #### Нарисуйте еще два графика. На первом должна быть общая капитализация биткойна (BTC), эфира (ETH), еос (EOS), биткойн кэша (BCH), стеллара (XLM) и лайткойна (LTC). На втором - доли капитализаций этих монет от общей капитализации рынка. При этом используйте данные начиная с 2017-07-01.

# %%
def plot_coins_capitalizations(coins, symbols, start_date):
    data = coins[(coins['symbol'].isin(symbols)) & (coins.index>=start_date)]
    
    fig = plt.figure(figsize=(50, 20))
    ax_1 = fig.add_subplot(2, 2, 1)
    for symbol in symbols:
        data_per_symbol = data[data['symbol'] == symbol]
        ax_1.plot(data_per_symbol['market'], label=symbol)
        
    ax_1.set_title('The Capitalization Of Coins', fontsize=40)
    ax_1.set_ylabel('Value', fontsize=30)
    ax_1.set_xlabel('Date', fontsize=30)
    plt.tick_params(axis='both', labelsize=18)
    ax_1.set_xticks(data.index[::len(data.index)//10])
    ax_1.legend(loc='upper left', fontsize=25)
    
    ax_1.grid()
    
    ax_2 = fig.add_subplot(2, 2, 3)
    for symbol in symbols:
        data_per_symbol = data[data['symbol'] == symbol]
        plt.plot(data_per_symbol['market'] / data.groupby('date')['market'].sum(), label=symbol)
    
    ax_2.set_title('Share Of Capitalization', fontsize=40)
    ax_2.set_ylabel('Value', fontsize=30)
    ax_2.set_xlabel('Date', fontsize=30)
    plt.tick_params(axis='both', labelsize=18)
    ax_2.set_xticks(data.index[::len(data.index)//10])
    ax_2.legend(loc='upper left', fontsize=18)
    
    plt.show()

# %%
plot_coins_capitalizations(
    coins=coins,
    symbols=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC'),
    start_date='2017-07-01'
)

# %% [markdown]
# #### Проанализируйте зависимость доли капитализации альткойнов от доли капитализации биткойна. Как выдумаете, в чём причина такой зависимости?

# %% [markdown]
# ## 7. Корреляции монет (1 балл)

# %% [markdown]
# #### Теперь нужно подробнее посмотреть на корреляции средних капитализаций монет. При этом будем смотреть на среднее сглаженное за последние window дней до дня date с коэффициентом сглаживания alpha для набора монет symbols.
# #### Реализуйте функцию, которая будет возвращать квадратный DataFrame с числом строк и столбцов равным числу рассматриваемых монет и со значениями корреляций.

# %%
def calc_coins_correlations(coins, date, symbols, window, alpha):
    data = coins[(coins['symbol'].isin(symbols)) & (coins.index<=date)]
    
    avg = list()
    for symbol in symbols:
        data_per_coin = data[data['symbol'] == symbol]
        data_per_coin = data_per_coin[data_per_coin.shape[0]-window:]
        avg.append(data_per_coin[['market']].ewm(alpha=alpha).mean())
    
    correlations = pd.DataFrame(index=[i for i in symbols])
    for i in range(len(symbols)):
        corr = list()
        for j in range(len(symbols)):
            corr.append(avg[i]['market'].corr(avg[j]['market']))
        correlations.insert(i, symbols[i], corr)
        
    print(correlations)
    return correlations

# %%
correlations = calc_coins_correlations(coins, date="2018-06-06",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
#           BTC       ETH       EOS       BCH       XLM       LTC       ADA
# BTC  1.000000  0.997899  0.096031  0.985504  0.978806  0.993636  0.974875
# ETH  0.997899  1.000000  0.081802  0.988940  0.982612  0.996569  0.975725
# EOS  0.096031  0.081802  1.000000  0.125192  0.121662  0.078436  0.175964
# BCH  0.985504  0.988940  0.125192  1.000000  0.995600  0.994693  0.988683
# XLM  0.978806  0.982612  0.121662  0.995600  1.000000  0.992905  0.993426
# LTC  0.993636  0.996569  0.078436  0.994693  0.992905  1.000000  0.985868
# ADA  0.974875  0.975725  0.175964  0.988683  0.993426  0.985868  1.000000
# <style  type="text/css" >
#     #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col0 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col1 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col2 {
#             background-color:  #3f53c6;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col3 {
#             background-color:  #ba162b;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col4 {
#             background-color:  #bd1f2d;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col5 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row0_col6 {
#             background-color:  #be242e;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col0 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col1 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col3 {
#             background-color:  #b8122a;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col4 {
#             background-color:  #bb1b2c;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col5 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row1_col6 {
#             background-color:  #be242e;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col2 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col3 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col4 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col5 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row2_col6 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col0 {
#             background-color:  #ba162b;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col1 {
#             background-color:  #b8122a;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col2 {
#             background-color:  #4961d2;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col3 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col4 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col5 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row3_col6 {
#             background-color:  #b8122a;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col0 {
#             background-color:  #bd1f2d;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col1 {
#             background-color:  #ba162b;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col2 {
#             background-color:  #4961d2;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col3 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col4 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col5 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row4_col6 {
#             background-color:  #b70d28;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col0 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col1 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col2 {
#             background-color:  #3b4cc0;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col3 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col4 {
#             background-color:  #b70d28;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col5 {
#             background-color:  #b40426;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row5_col6 {
#             background-color:  #ba162b;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col0 {
#             background-color:  #be242e;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col1 {
#             background-color:  #bd1f2d;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col2 {
#             background-color:  #5b7ae5;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col3 {
#             background-color:  #b8122a;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col4 {
#             background-color:  #b50927;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col5 {
#             background-color:  #b8122a;
#         }    #T_17b10700_7a77_11e9_bc02_5076af740c65row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_17b10700_7a77_11e9_bc02_5076af740c65" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >BTC</th>
#         <th class="col_heading level0 col1" >ETH</th>
#         <th class="col_heading level0 col2" >EOS</th>
#         <th class="col_heading level0 col3" >BCH</th>
#         <th class="col_heading level0 col4" >XLM</th>
#         <th class="col_heading level0 col5" >LTC</th>
#         <th class="col_heading level0 col6" >ADA</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_17b10700_7a77_11e9_bc02_5076af740c65level0_row0" class="row_heading level0 row0" >BTC</th>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col0" class="data row0 col0" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col1" class="data row0 col1" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col2" class="data row0 col2" >0.096</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col3" class="data row0 col3" >0.99</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col4" class="data row0 col4" >0.98</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col5" class="data row0 col5" >0.99</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row0_col6" class="data row0 col6" >0.97</td>
#     </tr>    <tr>
#         <th id="T_17b10700_7a77_11e9_bc02_5076af740c65level0_row1" class="row_heading level0 row1" >ETH</th>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col0" class="data row1 col0" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col1" class="data row1 col1" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col2" class="data row1 col2" >0.082</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col3" class="data row1 col3" >0.99</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col4" class="data row1 col4" >0.98</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col5" class="data row1 col5" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row1_col6" class="data row1 col6" >0.98</td>
#     </tr>    <tr>
#         <th id="T_17b10700_7a77_11e9_bc02_5076af740c65level0_row2" class="row_heading level0 row2" >EOS</th>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col0" class="data row2 col0" >0.096</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col1" class="data row2 col1" >0.082</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col2" class="data row2 col2" >1</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col3" class="data row2 col3" >0.13</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col4" class="data row2 col4" >0.12</td>
#         <td id="T_17b10700_7a77_11e9_bc02_5076af740c65row2_col5" class="data row

# %% [markdown]
# Довольно интересно ещё взглянуть на 2017-12-27:

# %%
correlations = calc_coins_correlations(coins, date="2017-12-27",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
#           BTC       ETH       EOS       BCH       XLM       LTC       ADA
# BTC  1.000000  0.588394  0.492214  0.267911  0.457099  0.662015  0.448765
# ETH  0.588394  1.000000  0.981043  0.905331  0.947791  0.984288  0.950256
# EOS  0.492214  0.981043  1.000000  0.952185  0.987220  0.933790  0.986093
# BCH  0.267911  0.905331  0.952185  1.000000  0.946369  0.825263  0.964980
# XLM  0.457099  0.947791  0.987220  0.946369  1.000000  0.886345  0.993952
# LTC  0.662015  0.984288  0.933790  0.825263  0.886345  1.000000  0.888555
# ADA  0.448765  0.950256  0.986093  0.964980  0.993952  0.888555  1.000000
# <style  type="text/css" >
#     #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col0 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row0_col6 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col0 {
#             background-color:  #ccd9ed;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col1 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col2 {
#             background-color:  #c12b30;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col3 {
#             background-color:  #df634e;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col4 {
#             background-color:  #d55042;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col5 {
#             background-color:  #c43032;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row1_col6 {
#             background-color:  #d44e41;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col0 {
#             background-color:  #a1c0ff;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col1 {
#             background-color:  #c43032;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col2 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col3 {
#             background-color:  #cb3e38;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col4 {
#             background-color:  #bd1f2d;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col5 {
#             background-color:  #ed8366;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row2_col6 {
#             background-color:  #bd1f2d;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col1 {
#             background-color:  #f29072;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col2 {
#             background-color:  #d55042;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col3 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col4 {
#             background-color:  #d65244;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col5 {
#             background-color:  #d8dce2;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row3_col6 {
#             background-color:  #cb3e38;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col0 {
#             background-color:  #90b2fe;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col1 {
#             background-color:  #de614d;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col2 {
#             background-color:  #bd1f2d;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col3 {
#             background-color:  #cd423b;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col4 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col5 {
#             background-color:  #f7b99e;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row4_col6 {
#             background-color:  #b70d28;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col0 {
#             background-color:  #e6d7cf;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col1 {
#             background-color:  #c12b30;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col2 {
#             background-color:  #df634e;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col3 {
#             background-color:  #f39577;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col4 {
#             background-color:  #ef886b;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col5 {
#             background-color:  #b40426;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row5_col6 {
#             background-color:  #ee8468;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col0 {
#             background-color:  #8caffe;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col1 {
#             background-color:  #dc5d4a;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col2 {
#             background-color:  #be242e;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col3 {
#             background-color:  #c53334;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col4 {
#             background-color:  #b70d28;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col5 {
#             background-color:  #f7b79b;
#         }    #T_296ea490_7a77_11e9_abdd_5076af740c65row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_296ea490_7a77_11e9_abdd_5076af740c65" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >BTC</th>
#         <th class="col_heading level0 col1" >ETH</th>
#         <th class="col_heading level0 col2" >EOS</th>
#         <th class="col_heading level0 col3" >BCH</th>
#         <th class="col_heading level0 col4" >XLM</th>
#         <th class="col_heading level0 col5" >LTC</th>
#         <th class="col_heading level0 col6" >ADA</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_296ea490_7a77_11e9_abdd_5076af740c65level0_row0" class="row_heading level0 row0" >BTC</th>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col0" class="data row0 col0" >1</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col1" class="data row0 col1" >0.59</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col2" class="data row0 col2" >0.49</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col3" class="data row0 col3" >0.27</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col4" class="data row0 col4" >0.46</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col5" class="data row0 col5" >0.66</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row0_col6" class="data row0 col6" >0.45</td>
#     </tr>    <tr>
#         <th id="T_296ea490_7a77_11e9_abdd_5076af740c65level0_row1" class="row_heading level0 row1" >ETH</th>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col0" class="data row1 col0" >0.59</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col1" class="data row1 col1" >1</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col2" class="data row1 col2" >0.98</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col3" class="data row1 col3" >0.91</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col4" class="data row1 col4" >0.95</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col5" class="data row1 col5" >0.98</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row1_col6" class="data row1 col6" >0.95</td>
#     </tr>    <tr>
#         <th id="T_296ea490_7a77_11e9_abdd_5076af740c65level0_row2" class="row_heading level0 row2" >EOS</th>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col0" class="data row2 col0" >0.49</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col1" class="data row2 col1" >0.98</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col2" class="data row2 col2" >1</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col3" class="data row2 col3" >0.95</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col4" class="data row2 col4" >0.99</td>
#         <td id="T_296ea490_7a77_11e9_abdd_5076af740c65row2_col5" class="dat

# %% [markdown]
# ## 8. Анализ одной стратегии (2 балла)

# %% [markdown]
# Разберем один мечтательный пример. Посмотрим какую прибыль могла бы нам принести хрестоматийная торговая стратегия основанная на скользящих средних. Стратегия выглядит следующим образом: мы строим две скользящие среднии для графика цены. С маленьким окном (ведущее скользящее среднее) и с бОльшим окном (запаздывающее скользящее среднее). Мы покупаем, когда ведущее среднее становится больше запаздывающего, и продаем в противном случае. Посмотрим на пример

# %%
def plot_moving_averages(coins, symbol, leading_window, lagging_window, start_date, end_date):
    coin = coins[coins['symbol'] == symbol][start_date:end_date]
    price = coin['price']
    leading_mean = price.rolling(window=leading_window).mean()
    lagging_mean = price.rolling(window=lagging_window).mean()

    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(111)
    
    ax.set_title('Price action for {}'.format(symbol))
    ax.plot(leading_mean, color='green', label='MA{}'.format(leading_window))
    ax.plot(lagging_mean, color='red', label='MA{}'.format(lagging_window))
    ax.plot(price, color='blue', label='price')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend(loc='best')
    ax.grid(True)
    plt.show() 

plot_moving_averages(
    coins=coins, 
    symbol='BTC', 
    leading_window=21, 
    lagging_window=50, 
    start_date='2017-05-01',
    end_date='2018-08-01')

# %% [markdown]
# Видно, что для скользящее среднее с бОльшим окном медленнее реагирует на изменение цены. Именно на этой идее и основана торговая стратегия.
# #### Реализуйте функцию, которая строит два графика. На правом будут изображены цена и скользящие средние. На левом - во сколько раз изменится размер вложений при использовании нашей стратегии и при обычном инвестировании
#
# #### Notes:
# Давайте использовать только цены закрытия. При этом, чтобы узнать цены за вчерашний день, стоит использовать метод shift(1) у Series.
# Отношение цен закрытия за сегодня и за вчера - это мой multiplier за сегодняшний день. При этом давайте строить графики накопления для multipliers. Т.е. если мы смотрим на 3 дня и в первый день multiplier = 1.5, во второй- 0.5 и в третий 2. То график будет выглядеть так: (1.5, 1.5 * 0.5, 1.5 * 0.5 * 2).
#
# При использовании нашей новой стратегии мы будем либо покупать, если ведущее среднее становится больше запаздующего на некоторый threshold (при этом лучше разницу сперва поделить на цену), либо оставлять всё как есть. При этом, конечно, нужно, принимая решения за сегодняшний день, смотреть только на статистику из прошлого.

# %%
def plot_moving_averages_strategy(
    coins, symbol, lead_window, lag_window, threshold, start_date, end_date
):
    data = coins[(coins['symbol'] == symbol) & (coins.index >= str(start_date)) & 
                 (coins.index <= str(end_date))]
    
    price = data['close']
    leading_mean = price.rolling(window=lead_window).mean()
    lagging_mean = price.rolling(window=lag_window).mean()

    fig = plt.figure(figsize=(50, 20))
    ax = fig.add_subplot(2, 2, 1)
    ax.plot(leading_mean, color='green', label='MA{}'.format(lead_window))
    ax.plot(lagging_mean, color='red', label='MA{}'.format(lag_window))
    ax.plot(price, color='blue', label='price')
    
    ax.set_title('Price action for {}'.format(symbol), fontsize=40)
    ax.set_xlabel('Date', fontsize=30)
    ax.set_ylabel('Value', fontsize=30)
    plt.tick_params(axis='both', labelsize=18)
    if (len(data.index)//10 > 0):
        ax.set_xticks(data.index[::len(data.index)//10])
    ax.legend(loc='best', fontsize=18)
    
    ax.grid()
    
    strategy_sales = [1]
    for diff in range(1, len(list(data['close']))):
        if (list(leading_mean-lagging_mean)[diff - 1] >= threshold):
            strategy_sales.append(strategy_sales[len(strategy_sales)-1] * (data['close'][diff-1: diff].values[0] / data['close'][diff: diff+1].values[0]))
        else:
            strategy_sales.append(strategy_sales[len(strategy_sales)-1])
    data.insert(12, 'strategy_sales', strategy_sales)
    
    multipliers = [1]
    for i in range(1, len(list(data['close']))):
        multipliers.append(multipliers[len(multipliers)-1] * (data['close'][i-1: i].values[0] / data['close'][i: i+1].values[0]))
    
    data.insert(13, 'multipliers', multipliers)
    
    ax_2 = fig.add_subplot(2, 2, 3)
    plt.plot(data['strategy_sales'] / data['multipliers'], label='ratio')
    ax_2.set_title('The Ratio Of Investment', fontsize=40)
    ax_2.set_ylabel('Value', fontsize=30)
    ax_2.set_xlabel('Date', fontsize=30)
    plt.tick_params(axis='both', labelsize=18)
    ax_2.set_xticks(data.index[::len(data.index)//10])
    ax_2.legend(loc='best', fontsize=18)
    
    plt.show()

# %%
# Теперь на основе реализованной функции сделаем интерактивные графики и поизучаем, что получилось:
symbol_selector = ipywidgets.Dropdown(
    options=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'),
    index=0,
    value='BTC',
    layout={'width': '700px'},
    continuous_update=False
)

lead_window_slider = ipywidgets.IntSlider(
    value=21, 
    min=1, 
    max=200, 
    step=1,
    layout={'width': '700px'},
    continuous_update=False)

lag_window_slider = ipywidgets.IntSlider(
    value=50,
    min=1, 
    max=200, 
    layout={'width': '700px'},
    step=1, continuous_update=False)

threshold_slider = ipywidgets.FloatSlider(
    min=0, 
    max=0.20, 
    step=0.001, 
    value=0.025,
    layout={'width': '700px'},
    continuous_update=False)

start_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2017-05-01'),
    layout={'width': '700px'},
    continuous_update=False
)

end_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2018-01-01'),
    layout={'width': '700px'},
    continuous_update=False
)

ipywidgets.interact(
    plot_moving_averages_strategy,
    coins=ipywidgets.fixed(coins),
    symbol=symbol_selector,
    lead_window=lead_window_slider,
    lag_window=lag_window_slider,
    threshold=threshold_slider,
    start_date=start_date_slider,
    end_date=end_date_slider
)
# Out:
# interactive(children=(Dropdown(description='symbol', layout=Layout(width='700px'), options=('BTC', 'ETH', 'EOS…
# <function __main__.plot_moving_averages_strategy(coins, symbol, lead_window, lag_window, threshold, start_date, end_date)>

# %% [markdown]
# #### Попробуйте разные значения параметров для разных монет и сделайте выводы о применимости такой модели.
# Дает хорошие результаты, когда есть длительные падения цен

# %% [markdown]
# ## 9. Отказ от ответственности
# Все примеры разобранных здесь стратегий являются игрушечными и не подходят для реальной торговли на бирже. Без серьезной подготовки вас там съедят с потрохами.

# %% [markdown]
# ![Disclamer](https://i0.kym-cdn.com/entries/icons/mobile/000/024/785/Screen_Shot_2017-11-30_at_1.12.37_PM.jpg)
